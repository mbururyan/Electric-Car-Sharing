# %%
# Initializing Pandas and Numpy Libraries

import pandas as pd
import numpy as np

# %%
# Loading the data onto the notebook

df = pd.read_csv('http://bit.ly/autolib_dataset')
df
# Out:
#                                  Address  Cars  Bluecar counter  \
# 0                    2 Avenue de Suffren     0                0
# 1              145 Rue Raymond Losserand     6                6
# 2       2 Avenue John Fitzgerald Kennedy     3                3
# 3                 51 Rue Eug̬ne Oudin̩     3                3
# 4     6 avenue de la Porte de Champerret     3                3
# ...                                  ...   ...              ...
# 4995                 8 avenue M̩nelotte     2                2
# 4996                   37 rue de Dantzig     4                4
# 4997                      142 rue du Bac     1                1
# 4998         2 avenue du Val de Fontenay     2                2
# 4999                 5 Rue Henry Brisson     4                4
#
#       Utilib counter  Utilib 1.4 counter  Charge Slots Charging Status  \
# 0                  0                   0             0     nonexistent
# ...

# %%
#Gathering general information about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %% [markdown]
# The Dataset Contains 5000 Rows and 25 Columns
#
# The datatypes are of integer type and object type

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Validity

# %%
# Dropping columns that are not important to us when data mining

# Columns are - > Displayed Comment, Scheduled at, Station type
# Drop Displayed Comment Column
df.drop(['Displayed comment'], inplace= True, axis=1)
df.head()
# Out:
#                               Address  Cars  Bluecar counter  Utilib counter  \
# 0                 2 Avenue de Suffren     0                0               0
# 1           145 Rue Raymond Losserand     6                6               0
# 2    2 Avenue John Fitzgerald Kennedy     3                3               0
# 3              51 Rue Eug̬ne Oudin̩     3                3               1
# 4  6 avenue de la Porte de Champerret     3                3               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status        City  \
# 0                   0             0     nonexistent       Paris
# 1                   0             0     operational       Paris
# 2                   2             0     operational  Le Bourget
# 3                   0             1     operational       Paris
# 4                   0             0     nonexistent       Paris
#
#                                   ID     Kind  ... Scheduled at  Slots  \
# ...

# %%
#Droppin the rest

df.drop(['Scheduled at', 'Station type', ], axis=1, inplace=True)
df.head()
# Out:
#                               Address  Cars  Bluecar counter  Utilib counter  \
# 0                 2 Avenue de Suffren     0                0               0
# 1           145 Rue Raymond Losserand     6                6               0
# 2    2 Avenue John Fitzgerald Kennedy     3                3               0
# 3              51 Rue Eug̬ne Oudin̩     3                3               1
# 4  6 avenue de la Porte de Champerret     3                3               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status        City  \
# 0                   0             0     nonexistent       Paris
# 1                   0             0     operational       Paris
# 2                   2             0     operational  Le Bourget
# 3                   0             1     operational       Paris
# 4                   0             0     nonexistent       Paris
#
#                                   ID     Kind  ...  \
# 0                    paris-suffren-2  STATION  ...
# ...

# %% [markdown]
# Columns Dropped from the dataset are :
# 1. Displayed Comment
# 2. Scheduled at
# 3. Station type

# %% [markdown]
# ## Accuracy

# %%
# Check and Fixing any mathematical errors in the dataset

# The cars columns should be equal to (Bluecars + Utilib + Utilib 1.4)

# Due to integrity issues, the column will remain untoutched

# %% [markdown]
# ## Completeness

# %%
# Checking for null values

df.isnull().sum()
# Out:
# Address                0
# Cars                   0
# Bluecar counter        0
# Utilib counter         0
# Utilib 1.4 counter     0
# Charge Slots           0
# Charging Status        0
# City                   0
# ID                     0
# Kind                   0
# Geo point              0
# Postal code            0
# Public name            0
# Rental status          0
# Slots                  0
# Status                 0
# Subscription status    0
# year                   0
# month                  0
# day                    0
# hour                   0
# minute                 0
# dtype: int64

# %% [markdown]
# The Dataset has no null values

# %% [markdown]
# ## Consistency

# %%
# Checking if there are any duplicates in the dataset

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates in the dataset

# %% [markdown]
# ## Uniformity

# %%
# Handling of data types

# Checking Dataset's Data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   ID                   5000 non-null   object
#  9   Kind                 5000 non-null   object
#  10  Geo point            5000 non-null   object
#  11  Postal code          5000 non-null   int64
#  12  Public name          5000 non-null   object
#  13  Rental status        5000 non-null   object
#  14  Slots                5000 non-null   int64
# ...

# %%
# Changing last 5 columns to date-time

df['new_datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour', 'minute']])

# %%
# Changing new_datetime to datetime datatype
df['new_datetime'] = pd.to_datetime(df['new_datetime'])
df.info()

# %%
# Print DataFrame with new datetime column
df.head()
# Out:
#                               Address  Cars  Bluecar counter  Utilib counter  \
# 0                 2 Avenue de Suffren     0                0               0
# 1           145 Rue Raymond Losserand     6                6               0
# 2    2 Avenue John Fitzgerald Kennedy     3                3               0
# 3              51 Rue Eug̬ne Oudin̩     3                3               1
# 4  6 avenue de la Porte de Champerret     3                3               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status        City  \
# 0                   0             0     nonexistent       Paris
# 1                   0             0     operational       Paris
# 2                   2             0     operational  Le Bourget
# 3                   0             1     operational       Paris
# 4                   0             0     nonexistent       Paris
#
#                                   ID     Kind  ... Rental status  Slots  \
# ...

# %%
# Exporting data to a new dataframe

df_new = df.to_csv('cleaned_autolib_dataset.csv')
df_new

# %% [markdown]
# ## Analysis

# %%
# Importing the cleaned dataset for analysis

df = pd.read_csv('/Users/RyanMburu/Documents/moringa-Independent-Projects/WK4-IP/cleaned_autolib_dataset.csv')
df.head()
# Out:
#    Unnamed: 0                             Address  Cars  Bluecar counter  \
# 0           0                 2 Avenue de Suffren     0                0
# 1           1           145 Rue Raymond Losserand     6                6
# 2           2    2 Avenue John Fitzgerald Kennedy     3                3
# 3           3              51 Rue Eug̬ne Oudin̩     3                3
# 4           4  6 avenue de la Porte de Champerret     3                3
#
#    Utilib counter  Utilib 1.4 counter  Charge Slots Charging Status  \
# 0               0                   0             0     nonexistent
# 1               0                   0             0     operational
# 2               0                   2             0     operational
# 3               1                   0             1     operational
# 4               0                   0             0     nonexistent
#
#          City                                 ID  ... Rental status Slots  \
# ...

# %%
# Most popular station

#Choosing only stations
df_station = df[df['Kind'] == 'STATION']
df_station

#Group the stations by count to find what station occurs most times

df_grouped = df_station.groupby('ID').count()
df_grouped

#Sorting the grouped stations

pop_stations = df_grouped.sort_values(by='Cars', ascending=0)
pop_stations.head()
# Out:
#                            Unnamed: 0  Address  Cars  Bluecar counter  \
# ID
# paris-portedemontrouge-8           13       13    13               13
# paris-philippeauguste-126          11       11    11               11
# paris-mathis-35                    11       11    11               11
# paris-courcelles-69                11       11    11               11
# sevres-wolfenbuttel-1              11       11    11               11
#
#                            Utilib counter  Utilib 1.4 counter  Charge Slots  \
# ID
# paris-portedemontrouge-8               13                  13            13
# paris-philippeauguste-126              11                  11            11
# paris-mathis-35                        11                  11            11
# paris-courcelles-69                    11                  11            11
# sevres-wolfenbuttel-1                  11                  11            11
#
#                            Charging Status  City  Kind  ...  Rental status  \
# ...

# %% [markdown]
# Most popular stations are :
# 1. paris-portedemontrouge-8  - 13 times
# 2. sevres-wolfenbuttel-1  -  11 times
# 3. paris-philippeauguste-126 -  11 times

# %%
#Least Popular stations

#Sort grouped stations in ascending order
least_pop_stations = df_grouped.sort_values(by='Cars', ascending=1)
least_pop_stations.head()
# Out:
#                             Unnamed: 0  Address  Cars  Bluecar counter  \
# ID
# yerres-raymondpoincare-200           1        1     1                1
# paris-bobillot-16                    1        1     1                1
# paris-gambetta-65                    1        1     1                1
# meudon-ponceau-2                     1        1     1                1
# meudon-jeannebraconnier-3            1        1     1                1
#
#                             Utilib counter  Utilib 1.4 counter  Charge Slots  \
# ID
# yerres-raymondpoincare-200               1                   1             1
# paris-bobillot-16                        1                   1             1
# paris-gambetta-65                        1                   1             1
# meudon-ponceau-2                         1                   1             1
# meudon-jeannebraconnier-3                1                   1             1
#
# ...

# %% [markdown]
# ### The least Popular stations in paris are
# 1. yerres-raymondpoincare-200 - once
# 2. paris-bobillot-16  -  once
# 3. paris-gambetta-65  -  once

# %%
# Most popular postal code

#Grouping postal code by count
group_postal = df.groupby('Postal code').count()
group_postal

#Sort in Descending order
pop_postal = group_postal.sort_values('Cars', ascending=0)
pop_postal.head()
# Out:
#              Unnamed: 0  Address  Cars  Bluecar counter  Utilib counter  \
# Postal code
# 75015               274      274   274              274             274
# 75016               236      236   236              236             236
# 75017               221      221   221              221             221
# 75011               180      180   180              180             180
# 75020               169      169   169              169             169
#
#              Utilib 1.4 counter  Charge Slots  Charging Status  City   ID  \
# Postal code
# 75015                       274           274              274   274  274
# 75016                       236           236              236   236  236
# 75017                       221           221              221   221  221
# 75011                       180           180              180   180  180
# 75020                       169           169              169   169  169
#
# ...

# %% [markdown]
# ### The most popular postal codes are :
# 1. 75015
# 2. 75016
# 3. 75017

# %%
# Least popular postal code
least_pop_postal = group_postal.sort_values(by='Cars', ascending=1)
least_pop_postal.head()
# Out:
#              Unnamed: 0  Address  Cars  Bluecar counter  Utilib counter  \
# Postal code
# 94100                 2        2     2                2               2
# 92110                 4        4     4                4               4
# 93310                 4        4     4                4               4
# 91400                 4        4     4                4               4
# 75116                 5        5     5                5               5
#
#              Utilib 1.4 counter  Charge Slots  Charging Status  City  ID  ...  \
# Postal code                                                               ...
# 94100                         2             2                2     2   2  ...
# 92110                         4             4                4     4   4  ...
# 93310                         4             4                4     4   4  ...
# 91400                         4             4                4     4   4  ...
# ...

# %% [markdown]
# ### The least popular postal codes are:
# 1. 94100
# 2. 92110
# 3. 93310

# %%
# Crucial Data Cleaning

# Separating datetime columns into date and time
df.head()

#date column
df['date'] = pd.to_datetime((df.year*10000+df.month*100+df.day).apply(str),format='%Y%m%d')
df.head(1)
# Out:
#    Unnamed: 0              Address  Cars  Bluecar counter  Utilib counter  \
# 0           0  2 Avenue de Suffren     0                0               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status   City               ID  \
# 0                   0             0     nonexistent  Paris  paris-suffren-2
#
#    ... Slots Status  Subscription status  year month  day hour minute  \
# 0  ...     2     ok          nonexistent  2018     4    8   11     43
#
#          new_datetime       date
# 0 2018-04-08 11:43:00 2018-04-08
#
# [1 rows x 25 columns]

# %%
# Changing new_datetime to datetime datatype
df['new_datetime'] = pd.to_datetime(df['new_datetime'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5000 non-null   int64
#  1   Address              5000 non-null   object
#  2   Cars                 5000 non-null   int64
#  3   Bluecar counter      5000 non-null   int64
#  4   Utilib counter       5000 non-null   int64
#  5   Utilib 1.4 counter   5000 non-null   int64
#  6   Charge Slots         5000 non-null   int64
#  7   Charging Status      5000 non-null   object
#  8   City                 5000 non-null   object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
#testing the time col

df['new_datetime'].dt.hour
# Out:
# 0       11
# 1        7
# 2       20
# 3        4
# 4       17
#         ..
# 4995    11
# 4996    16
# 4997     7
# 4998    17
# 4999    10
# Name: new_datetime, Length: 5000, dtype: int64

# %%
# Most popular hour for picking blue cars

#groupby hour
grp_hour_blue_pick = df.groupby('hour')[['Bluecar counter']].sum()
grp_hour_blue_pick

#sort hours by bluecars
pop_hour_blue = grp_hour_blue_pick.sort_values(by='Bluecar counter', ascending=0)
pop_hour_blue.head()
# Out:
#       Bluecar counter
# hour
# 6                 608
# 2                 559
# 7                 555
# 5                 552
# 3                 549

# %% [markdown]
# #### Most popular hour for bluecars is 6AM

# %%
# Least popular hour for bluecars
least_pop_hour_blue = grp_hour_blue_pick.sort_values(by='Bluecar counter', ascending=1)
least_pop_hour_blue.head()
# Out:
#       Bluecar counter
# hour
# 19                387
# 20                411
# 14                418
# 18                427
# 17                432

# %% [markdown]
# #### Least popular hour for blue cars is 1900 HRS / 9 PM

# %%
# Popular hour for Utilib cars

#Grouped per hour
grp_hour_utilib = df.groupby('hour')[['Utilib counter']].sum()
grp_hour_utilib

#Ranked from most popular
pop_hour_utilib = grp_hour_utilib.sort_values(by='Utilib counter', ascending=0)
pop_hour_blue.head()
# Out:
#       Bluecar counter
# hour
# 6                 608
# 2                 559
# 7                 555
# 5                 552
# 3                 549

# %% [markdown]
# #### Most popular hour for Utilib cars is 6 AM

# %%
# Least popular hour for Utilib cars
least_pop_hour_utilib = grp_hour_utilib.sort_values(by='Utilib counter', ascending=1)
least_pop_hour_utilib.head()
# Out:
#       Utilib counter
# hour
# 23                 2
# 4                  6
# 12                 7
# 19                 8
# 20                 9

# %% [markdown]
# #### Least popular hour when a Utilib vehicle was picked is 2300 HRS / 11 PM

# %%
# Most popular hour for utilib 1.4 

group_utilib_4 = df.groupby('hour')[['Utilib 1.4 counter']].sum()
group_utilib_4

pop_hour_utilib_4 = group_utilib_4.sort_values(by='Utilib 1.4 counter', ascending=0)
pop_hour_utilib_4.head()
# Out:
#       Utilib 1.4 counter
# hour
# 3                     36
# 5                     34
# 6                     31
# 14                    31
# 9                     31

# %% [markdown]
# #### Most popular hour for utilib 1.4 vehicles is 3 AM

# %%
# least popular hour for utilib 1.4
least_pop_hour_utilib_4 = group_utilib_4.sort_values(by='Utilib 1.4 counter', ascending=1)
least_pop_hour_utilib_4.head()
# Out:
#       Utilib 1.4 counter
# hour
# 12                    17
# 11                    18
# 23                    18
# 8                     19
# 15                    20

# %% [markdown]
# #### Least popular hour for utilib 1.4 is 1700 HRS / 5 PM

# %%
# Most popular station during popular picking hour for blue cars
# Most popular hour is 8 AM
pop_hour = df.loc[df.hour == 6]
pop_hour

pop_hour.groupby('ID')['Bluecar counter'].sum().sort_values(ascending=False).head()
# Out:
# ID
# garches-raymondpoincare-102               11
# clichylagarenne-jeanjaures-122            11
# leplessisrobinson-chausseedeletang-109     9
# lagarennecolombes-verdun-41                8
# paris-julienlacroix-39                     8
# Name: Bluecar counter, dtype: int64

# %% [markdown]
# #### At 6AM which is the most popular picking hour, the most popular station during that time is :
#
# garches-raymondpoincare-102

# %%
# Least popular station during the popular picking hour

pop_hour.groupby('ID')['Bluecar counter'].sum().sort_values(ascending=True).head()
# Out:
# ID
# paris-marceau-1                   0
# paris-notredamedesvictoires-21    0
# paris-crozatier-33                0
# paris-clovis-20                   0
# paris-chateaubriand-19            0
# Name: Bluecar counter, dtype: int64

# %%
# Most popular postal code for picking blue cars during most popular hour

pop_hour.groupby('Postal code')['Bluecar counter'].sum().sort_values(ascending=False).head()
# Out:
# Postal code
# 75015    44
# 75020    40
# 75016    39
# 75017    30
# 92500    26
# Name: Bluecar counter, dtype: int64

# %% [markdown]
# #### During 6 AM, the most popular postal code is 75015

# %% [markdown]
# ## Data Vizualization

# %%
# Load plotting libraries 

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plotting bar graphs for popular hour when blue cars are picked 

grp_hour_blue_pick.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='hour'>

# %% [markdown]
# #### As seen, the most popular hour is 6 AM, and the least popular is 7 PM

# %%
# Bar graph for Utilib cars 
grp_hour_utilib.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='hour'>

# %% [markdown]
# #### The graph shows 8 AM as most popular hour and 11PM as least popular hour

# %%
# Bar graph for Utilib 1.4

group_utilib_4.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='hour'>

# %% [markdown]
# ### The graph shows 3AM as most popular hour and 12PM as least popular hours
